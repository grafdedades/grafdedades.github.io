# %% [markdown]
# # 🛠️ Graf de Dades - Admin Dashboard
#
# Notebook d'administració per gestió avançada del graf.
#
# ## Funcionalitats
#
# 1. **Gestió JSON**: Exportar/Importar dades en format JSON pla per edició manual externa.
# 2. **Gestió Arestes**: Modificar o eliminar arestes existents.
# 3. **Gestió Usuaris**: Eliminar completament usuaris (i les seves connexions).
#
# > ⚠️ **Backup**: Recorda fer còpies de seguretat abans de fer canvis dràstics.

# %%
# Import setup
from tools.graph_update_utils import (
    show_load_section,
    show_admin_json_section,
    show_edge_search_section,
    show_admin_user_section
)

# %% [markdown]
# ---
# ## 1. Carregar Dades Principal
#
# Load data from `graph_data.enc`. Use the **Standard Save** button here to persist changes permanently back to the encrypted file.

# %%
show_load_section()

# %% [markdown]
# ---
# ## 2. Sincronització JSON
#
# Exporta dades a `data/decrypted_graph.json` per editar amb VS Code o un altre editor extern.
# Un cop editat, importa les dades de nou per actualitzar la memòria del notebook.
#
# Els canvis després d'importar les dades s'han de desar a la primera secció.

# %%
show_admin_json_section()

# %% [markdown]
# ---
# ## 3. Modificar / Eliminar Arestes
#
# Busca una aresta concreta i edita els seus valors o elimina-la.

# %%
show_edge_search_section(admin_mode=True)

# %% [markdown]
# ---
# ## 4. Eliminar Usuari (DANGER ZONE)
#
# Elimina un node i **totes** les arestes connectades a ell. Irreversible sense backup.

# %%
show_admin_user_section()
