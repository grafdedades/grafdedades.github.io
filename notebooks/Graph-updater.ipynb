# %% [markdown]
# # 📊 Graf de Dades - Actualitzador
#
# Aquesta notebook permet actualitzar el graf de dades de forma interactiva.
#
# ## Instruccions
#
# 1. **Carrega les dades** - Introdueix la contrasenya i clica "Desencripta!"
# 2. **Fes els canvis** - Afegeix nodes, arestes o anonimitza persones
# 3. **Desa els canvis** - Clica "Desa els canvis!" per encriptar i guardar
#
# > ⚠️ **Important**: Recorda fer `Kernel > Restart & Clear Output` o `Discard git changes on notebook` al acabar!

# %%
# Importa les utilitats
import sys
import os
sys.path.append(os.path.abspath('..'))
from tools.graph_update_utils import (
    show_load_section,
    show_node_section,
    show_edge_add_section,
    show_edge_search_section,
    show_anonymize_section
)

# %% [markdown]
# ---
# ## 🔐 1. Carregar Dades
#
# Introdueix la contrasenya i clica el botó per desencriptar les dades.

# %%
show_load_section()

# %% [markdown]
# ---
# ## 👤 2. Afegir Nodes (Persones)
#
# Afegeix noves persones al graf.

# %%
show_node_section()

# %% [markdown]
# ---
# ## ➕ 3. Afegir Nova Aresta
#
# Crea una nova connexió entre dues persones:
# - **Punts**: Lio(1), Manual(2), Oral(3), Complert(5)

# %%
show_edge_add_section()

# %% [markdown]
# ---
# ## 🔍 4. Buscar arestes
#
# Busca una aresta existent per veure els seus detalls.

# %%
show_edge_search_section()

# %% [markdown]
# ---
# ## 🕵️ 5. Anonimitzar Persones
#
# Si una persona vol sortir del graf públic, apareixerà com "Anònim X".

# %%
show_anonymize_section()

# %% [markdown]
# ---
# ## ✅ Fi
#
# Quan hagis acabat:
# 1. Clica **"💾 Desa els canvis!"** a la secció 1
# 2. Fes `Kernel > Restart & Clear Output` o `Discard All git Changes` per netejar la notebook
